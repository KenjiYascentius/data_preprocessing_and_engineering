# %% [markdown]
# ## Eksplorasi Data

# %% [markdown]
# ### Use Full data

# %%
from pandas import read_csv

data = read_csv('north_20000.csv')
display (data.head(5))
print(data.shape)
print(data.describe())

# %% [markdown]
# ### Use Smaller Data

# %%
from pandas import read_csv
import pandas as pd

# ubah seting supaya bisa melihat semua kolom
pd.set_option('display.max_columns', None)

data = read_csv('north_20000.csv',header=None)
display(data.head(1))
data = data[1:]
display (data.head(20))
print(data.shape)
display(data.describe())
# Out:
#       0     1     2                                 3   \
# 0  index  Data  Hora  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
#
#                                                   4   \
# 0  PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORAR...
#
#                                                 5   \
# 0  PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
#
#                                                  6                        7   \
# 0  PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m²)
#
#                                              8   \
# 0  TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
#
#                                      9   \
# 0  TEMPERATURA DO PONTO DE ORVALHO (°C)
#
#                                            10  \
# 0  TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
#
#                                            11  \
# 0  TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
#
#                                                  12  \
# 0  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
#
#                                                  13  \
# 0  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
#
#                                          14  \
# 0  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
#
#                                          15  \
# 0  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
#
#                                     16                                    17  \
# 0  UMIDADE RELATIVA DO AR, HORARIA (%)  VENTO, DIREÇÃO HORARIA (gr) (° (gr))
#
#                            18                               19      20     21  \
# 0  VENTO, RAJADA MAXIMA (m/s)  VENTO, VELOCIDADE HORARIA (m/s)  region  state
#
#         22            23        24         25      26
# 0  station  station_code  latitude  longitude  height
#     0           1      2        3        4        5        6      7        8   \
# 1    0  2000-05-09  00:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 2    1  2000-05-09  01:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 3    2  2000-05-09  02:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 4    3  2000-05-09  03:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 5    4  2000-05-09  04:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 6    5  2000-05-09  05:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 7    6  2000-05-09  06:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 8    7  2000-05-09  07:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 9    8  2000-05-09  08:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 10   9  2000-05-09  09:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 11  10  2000-05-09  10:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 12  11  2000-05-09  11:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 13  12  2000-05-09  12:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 14  13  2000-05-09  13:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 15  14  2000-05-09  14:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 16  15  2000-05-09  15:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 17  16  2000-05-09  16:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 18  17  2000-05-09  17:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 19  18  2000-05-09  18:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 20  19  2000-05-09  19:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
#
#          9        10       11       12       13     14     15     16     17  \
# 1   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 2   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 3   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 4   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 5   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 6   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 7   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 8   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 9   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 10  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 11  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 12  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 13  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 14  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 15  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 16  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 17  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 18  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 19  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 20  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
#
#          18       19 20  21      22    23           24            25     26
# 1   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 2   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 3   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 4   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 5   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 6   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 7   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 8   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 9   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 10  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 11  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 12  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 13  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 14  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 15  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 16  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 17  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 18  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 19  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 20  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# (19999, 27)
#            0           1      2      3        4        5        6      7   \
# count   19999       19999  19999  19999    19999    19999    19999  19999
# unique   8760         834     24    108      167      163      163   3067
# top         0  2000-05-09  00:00    0.0  -9999.0  -9999.0  -9999.0  -9999
# freq        3          24    834  14243     4740     5194     5194  12005
#
#              8        9        10       11       12       13     14     15  \
# count     19999    19999    19999    19999    19999    19999  19999  19999
# unique      162       89      161      161       92       87     63     65
# top     -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999
# freq       4730     4818     5192     5192     5281     5281   5280   5280
#
#            16     17       18       19     20     21      22     23  \
# count   19999  19999    19999    19999  19999  19999   19999  19999
# unique     64    361      247       65      1      1       1      1
# top     -9999  -9999  -9999.0  -9999.0      N     AM  MANAUS   A101
# freq     4818   4790     4904     4743  19999  19999   19999  19999
#
#                  24            25     26
# count         19999         19999  19999
# unique            1             1      1
# top     -3.10333333  -60.01638888  61.25
# freq          19999         19999  19999

# %% [markdown]
# Diatas kita melihat ada beberapa kolom yang memiliki nilai -9999 yaitu untuk kolom:
# - Amount of precipitation in millimetres (last hour)
# - Atmospheric pressure at station level (mb)
# - Maximum air pressure for the last hour (mb)
# - Minimum air pressure for the last hour (mb)
# - Solar radiation (KJ/m2)
# - Air temperature (instant) (°c)
# - Dew point temperature (instant) (°c)
# - Maximum temperature for the last hour (°c)
# - Minimum temperature for the last hour (°c)
# - Maximum dew point temperature for the last hour (°c)
# - Minimum dew point temperature for the last hour (°c)
# - Maximum relative humid temperature for the last hour (%)
# - Minimum relative humid temperature for the last hour (%)
# - Relative humid (% instant)
# - Wind direction (radius degrees (0-360))
# - Wind gust in metres per second
# - Wind speed in metres per second
#
# Untuk setiap kolom diatas, nilai -9999 tidak masuk akal sehingga bisa simpulkan bahwa nilai -9999 merupakan _missing value_

# %%
from numpy import nan

indices = []
for i in range(3,20):
    indices.append(i)

# num_missing = (data[index] == -9999.0).sum()

data[indices] = data[indices].replace(-9999,"nan")

display(data.head(20))
# print(num_missing)
# Out:
#     0           1      2        3        4        5        6      7        8   \
# 1    0  2000-05-09  00:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 2    1  2000-05-09  01:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 3    2  2000-05-09  02:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 4    3  2000-05-09  03:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 5    4  2000-05-09  04:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 6    5  2000-05-09  05:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 7    6  2000-05-09  06:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 8    7  2000-05-09  07:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 9    8  2000-05-09  08:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 10   9  2000-05-09  09:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 11  10  2000-05-09  10:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 12  11  2000-05-09  11:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 13  12  2000-05-09  12:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 14  13  2000-05-09  13:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 15  14  2000-05-09  14:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 16  15  2000-05-09  15:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 17  16  2000-05-09  16:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 18  17  2000-05-09  17:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 19  18  2000-05-09  18:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
# 20  19  2000-05-09  19:00  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999.0
#
#          9        10       11       12       13     14     15     16     17  \
# 1   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 2   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 3   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 4   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 5   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 6   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 7   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 8   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 9   -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 10  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 11  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 12  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 13  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 14  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 15  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 16  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 17  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 18  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 19  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
# 20  -9999.0  -9999.0  -9999.0  -9999.0  -9999.0  -9999  -9999  -9999  -9999
#
#          18       19 20  21      22    23           24            25     26
# 1   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 2   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 3   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 4   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 5   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 6   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 7   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 8   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 9   -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 10  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 11  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 12  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 13  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 14  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 15  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 16  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 17  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 18  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 19  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25
# 20  -9999.0  -9999.0  N  AM  MANAUS  A101  -3.10333333  -60.01638888  61.25

# %%
# Print kolom yang single value
print("Single Value")
for i in range (len(data.nunique())):
    if data.nunique()[i] == 1:
        print(f"{i}: {data.nunique()[i]}")

# Cari baris yang duplikat
duplicates = data.duplicated()
print("\nAny Duplicates? ", duplicates.any())
# Out:
# Single Value
# 20: 1
# 21: 1
# 22: 1
# 23: 1
# 24: 1
# 25: 1
# 26: 1
#
# Any Duplicates?  False

# %% [markdown]
# Dalam data tidak ditemukan baris yang duplikat namun ditemukan 7 kolom yang bersifat single-value

# %% [markdown]
# ### Identifikasi Outlier

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor
data = lof.fit_predict(data)
display(data.head(5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [35], line 4
#       1 from sklearn.neighbors import LocalOutlierFactor
#       3 lof = LocalOutlierFactor
# ----> 4 data = lof.fit_predict(data)
#       5 display(data.head(5))
#
# File C:\ProgramData\Miniconda3\envs\preprocessing\lib\site-packages\sklearn\utils\_available_if.py:40, in _AvailableIfDescriptor.__get__.<locals>.out(*args, **kwargs)
#      38 @wraps(self.fn)
#      39 def out(*args, **kwargs):
# ---> 40     if not self.check(args[0]):
#      41         raise attr_err
#      42     return self.fn(*args, **kwargs)
#
# File C:\ProgramData\Miniconda3\envs\preprocessing\lib\site-packages\sklearn\neighbors\_lof.py:222, in LocalOutlierFactor._check_novelty_fit_predict(self)
#     221 def _check_novelty_fit_predict(self):
# --> 222     if self.novelty:
#     223         msg = (
#     224             "fit_predict is not available when novelty=True. Use "
#     225             "novelty=False if you want to predict on the training set."
#     226         )
#     227         raise AttributeError(msg)
#
# File C:\ProgramData\Miniconda3\envs\preprocessing\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'novelty'
